# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). While it seems like the northern hemisphere tends to be warmer this time of year in the scatter plot than the southern hemisphere, it is very important to note that there is no data available for cities in the southern hemisphere between -60 degrees and - 90 degrees latitude (as compared to the relative abundance of data, all the way up to 80 degrees latitude in the northern hemisphere.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 20, 40, ~80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed.
# * There is no strong relationship between latitude and humidity.
# * It is interesting to see that, when looking at longitude vs. max. temp, most cities analyzed have temperatures between 0 and 50C for this time of the year, indicating the cities analyzed are mostly from the parts of the word experiencing the summer season.
# * Also, while looking at longitude vs. other variables(humidity, cloudiness), there does not seem to be any disceranble trends.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = os.path.join("Output Data","cities.csv")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs, 
lat_lngs = []
cities = []
countries = []
citycountry = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city,associated country and a combined "city,country" string for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    city_country=str(city) + "," + str(country)
    # If the city is unique, then add it to our cities list, 
    if city not in cities:
        cities.append(city)
        countries.append(country)
        citycountry.append(city_country)

# Print the city count to confirm sufficient count
print(f'The number of cities is {len(cities)}.')
# Out:
# The number of cities is 634.

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}&appid={api_key}&units={units}&q="



# create lists to hold lat, lon, windspeed, cloudiness, etc.
Lat = []
Lon = []
Temp = []
Wind = []
Cloud = []
Hum = []
City = []
Country = []
Date = []


#set the counter to zero for record number keeping
counter = 1

print(f'Beginning Data Retrieval')
print(f'---------------------------')


for city in citycountry:
    try:
        # assemble url and make API request, add to the respective lists, and create print log for each API call
        finalurl= query_url + city
        response = requests.get(finalurl).json()
        print(f"Processing record no.{counter}|{city}.")
        counter = counter + 1
        Lat.append(response['coord']['lat'])
        Lon.append(response['coord']['lon'])
        Temp.append(response['main']['temp_max'])
        Wind.append(response['wind']['speed'])
        Cloud.append(response['clouds']['all'])
        Hum.append(response['main']['humidity'])
        City.append(response['name'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
        time.sleep(1.01)
    except:
        print("City not found... skipping.")

print('--------------------------')
print('Data Retrieval Complete')
print('--------------------------')
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing record no.1|puerto ayora,ec.
# Processing record no.2|palmer,us.
# Processing record no.3|mataura,pf.
# City not found... skipping.
# Processing record no.4|tsihombe,mg.
# City not found... skipping.
# Processing record no.5|chokurdakh,ru.
# Processing record no.6|noicattaro,it.
# Processing record no.7|barrow,us.
# Processing record no.8|mecca,sa.
# Processing record no.9|nikolskoye,ru.
# Processing record no.10|ushuaia,ar.
# Processing record no.11|skibbereen,ie.
# Processing record no.12|dikson,ru.
# Processing record no.13|paita,pe.
# Processing record no.14|kichera,ru.
# Processing record no.15|taolanaro,mg.
# City not found... skipping.
# Processing record no.16|cape town,za.
# Processing record no.17|naze,jp.
# Processing record no.18|airai,pw.
# City not found... skipping.
# Processing record no.19|poronaysk,ru.
# Processing record no.20|ribeira grande,pt.
# Processing record no.21|kapaa,us.
# Processing record no.22|flinders,au.
# Processing record no.23|benguela,ao.
# Processing record no.24|dilla,et.
# Processing record no.25|pilar,ph.
# Processing record no.26|rikitea,pf.
# Processing record no.27|grand-lahou,ci.
# Processing record no.28|belushya guba,ru.
# City not found... skipping.
# Processing record no.29|ancud,cl.
# Processing record no.30|rio gallegos,ar.
# Processing record no.31|port elizabeth,za.
# Processing record no.32|isangel,vu.
# Processing record no.33|busselton,au.
# Processing record no.34|punta arenas,cl.
# Processing record no.35|port alfred,za.
# Processing record no.36|chumikan,ru.
# Processing record no.37|alice springs,au.
# Processing record no.38|mahebourg,mu.
# Processing record no.39|albany,au.
# Processing record no.40|umm lajj,sa.
# Processing record no.41|rawson,ar.
# Processing record no.42|namibe,ao.
# Processing record no.43|vaini,to.
# Processing record no.44|saint-philippe,re.
# Processing record no.45|neuquen,ar.
# Processing record no.46|georgetown,sh.
# Processing record no.47|salalah,om.
# Processing record no.48|tabou,ci.
# Processing record no.49|pemangkat,id.
# City not found... skipping.
# Processing record no.50|arenys de mar,es.
# Processing record no.51|ascension,mx.
# City not found... skipping.
# Processing record no.52|cabo san lucas,mx.
# Processing record no.53|khatanga,ru.
# Processing record no.54|avarua,ck.
# Processing record no.55|solnechnyy,ru.
# Processing record no.56|zhigansk,ru.
# Processing record no.57|inderborskiy,kz.
# City not found... skipping.
# Processing record no.58|ostrovnoy,ru.
# Processing record no.59|lazarea,ro.
# Processing record no.60|tomatlan,mx.
# Processing record no.61|belle glade,us.
# Processing record no.62|ahipara,nz.
# Processing record no.63|carnarvon,au.
# Processing record no.64|dingle,ie.
# Processing record no.65|meulaboh,id.
# Processing record no.66|xining,cn.
# Processing record no.67|abhaynagar,bd.
# Processing record no.68|sitka,us.
# Processing record no.69|lebu,cl.
# Processing record no.70|sann,pk.
# Processing record no.71|erzin,ru.
# Processing record no.72|sao gabriel da cachoeira,br.
# Processing record no.73|padang,id.
# Processing record no.74|torbay,ca.
# Processing record no.75|hamilton,bm.
# Processing record no.76|burns lake,ca.
# Processing record no.77|kodiak,us.
# Processing record no.78|kamenskoye,ru.
# City not found... skipping.
# Processing record no.79|tuktoyaktuk,ca.
# Processing record no.80|lorengau,pg.
# Processing record no.81|klaksvik,fo.
# Processing record no.82|samusu,ws.
# City not found... skipping.
# Processing record no.83|mehamn,no.
# Processing record no.84|barguzin,ru.
# Processing record no.85|butaritari,ki.
# Processing record no.86|katsuura,jp.
# Processing record no.87|marshall,us.
# Processing record no.88|acapulco,mx.
# Processing record no.89|bluff,nz.
# Processing record no.90|chuy,uy.
# Processing record no.91|san patricio,mx.
# Processing record no.92|pathein,mm.
# Processing record no.93|quatre cocos,mu.
# Processing record no.94|sassandra,ci.
# Processing record no.95|luangwa,zm.
# Processing record no.96|norden,de.
# Processing record no.97|chulman,ru.
# Processing record no.98|shingu,jp.
# Processing record no.99|victoria,sc.
# Processing record no.100|shelburne,ca.
# Processing record no.101|sobolevo,ru.
# Processing record no.102|anuradhapura,lk.
# Processing record no.103|arraial do cabo,br.
# Processing record no.104|hilo,us.
# Processing record no.105|hermanus,za.
# Processing record no.106|auki,sb.
# Processing record no.107|awjilah,ly.
# Processing record no.108|hobart,au.
# Processing record no.109|olinda,br.
# Processing record no.110|florianopolis,br.
# Processing record no.111|kindu,cd.
# Processing record no.112|souillac,mu.
# Processing record no.113|buala,sb.
# Processing record no.114|nizhneyansk,ru.
# City not found... skipping.
# Processing record no.115|beyneu,kz.
# Processing record no.116|upernavik,gl.
# Processing record no.117|saskylakh,ru.
# Processing record no.118|eenhana,na.
# Processing record no.119|kahului,us.
# Processing record no.120|thompson,ca.
# Processing record no.121|pevek,ru.
# Processing record no.122|thyboron,dk.
# Processing record no.123|bandarbeyla,so.
# Processing record no.124|kavieng,pg.
# Processing record no.125|narsaq,gl.
# Processing record no.126|saint george,bm.
# Processing record no.127|marzuq,ly.
# City not found... skipping.
# Processing record no.128|najran,sa.
# Processing record no.129|aden,ye.
# Processing record no.130|monitos,co.
# Processing record no.131|bredasdorp,za.
# Processing record no.132|lizzano,it.
# Processing record no.133|tonj,sd.
# City not found... skipping.
# Processing record no.134|englewood,us.
# Processing record no.135|tawkar,sd.
# City not found... skipping.
# Processing record no.136|hay river,ca.
# Processing record no.137|esperance,au.
# Processing record no.138|massakory,td.
# Processing record no.139|ponta do sol,cv.
# Processing record no.140|bilibino,ru.
# Processing record no.141|varzea da palma,br.
# Processing record no.142|roald,no.
# Processing record no.143|chengde,cn.
# Processing record no.144|borba,br.
# Processing record no.145|komsomolskiy,ru.
# Processing record no.146|tezu,in.
# Processing record no.147|palabuhanratu,id.
# City not found... skipping.
# Processing record no.148|khani,ru.
# City not found... skipping.
# Processing record no.149|nadym,ru.
# Processing record no.150|new iberia,us.
# Processing record no.151|ilo,pe.
# Processing record no.152|playa vicente,mx.
# Processing record no.153|portland,au.
# Processing record no.154|luderitz,na.
# Processing record no.155|zhezkazgan,kz.
# Processing record no.156|tuy hoa,vn.
# Processing record no.157|nishihara,jp.
# Processing record no.158|mbini,gq.
# Processing record no.159|stokmarknes,no.
# Processing record no.160|vaitupu,wf.
# City not found... skipping.
# Processing record no.161|saleaula,ws.
# City not found... skipping.
# Processing record no.162|mys shmidta,ru.
# City not found... skipping.
# Processing record no.163|zaysan,kz.
# Processing record no.164|bolshiye uki,ru.
# City not found... skipping.
# Processing record no.165|east london,za.
# Processing record no.166|soyo,ao.
# Processing record no.167|hudson bay,ca.
# Processing record no.168|phrai bung,th.
# City not found... skipping.
# Processing record no.169|novita,co.
# Processing record no.170|sao joao da barra,br.
# Processing record no.171|atuona,pf.
# Processing record no.172|jamestown,sh.
# Processing record no.173|yantal,ru.
# Processing record no.174|hirara,jp.
# Processing record no.175|haibowan,cn.
# City not found... skipping.
# Processing record no.176|vyshkov,ru.
# Processing record no.177|west bay,ky.
# Processing record no.178|canoinhas,br.
# Processing record no.179|illoqqortoormiut,gl.
# City not found... skipping.
# Processing record no.180|baturaja,id.
# Processing record no.181|ilulissat,gl.
# Processing record no.182|yirol,sd.
# City not found... skipping.
# Processing record no.183|fairbanks,us.
# Processing record no.184|hofn,is.
# Processing record no.185|bulgan,mn.
# Processing record no.186|northam,au.
# Processing record no.187|labuan,my.
# Processing record no.188|pangnirtung,ca.
# Processing record no.189|mendoza,ar.
# Processing record no.190|jiexiu,cn.
# Processing record no.191|kedougou,sn.
# Processing record no.192|vila velha,br.
# Processing record no.193|siguiri,gn.
# Processing record no.194|provideniya,ru.
# Processing record no.195|lavrentiya,ru.
# Processing record no.196|totness,sr.
# Processing record no.197|tamworth,au.
# Processing record no.198|tura,ru.
# Processing record no.199|vicuna,cl.
# Processing record no.200|castro,cl.
# Processing record no.201|mokhsogollokh,ru.
# Processing record no.202|ust-nera,ru.
# Processing record no.203|qaanaaq,gl.
# Processing record no.204|ketchikan,us.
# Processing record no.205|nalut,ly.
# Processing record no.206|obodivka,ua.
# Processing record no.207|carupano,ve.
# Processing record no.208|barentsburg,sj.
# City not found... skipping.
# Processing record no.209|hithadhoo,mv.
# Processing record no.210|port hedland,au.
# Processing record no.211|mar del plata,ar.
# Processing record no.212|la ronge,ca.
# Processing record no.213|dukat,ru.
# Processing record no.214|roebourne,au.
# Processing record no.215|price,us.
# Processing record no.216|new norfolk,au.
# Processing record no.217|andenes,no.
# Processing record no.218|goderich,sl.
# City not found... skipping.
# Processing record no.219|boke,gn.
# Processing record no.220|trincomalee,lk.
# Processing record no.221|bubaque,gw.
# Processing record no.222|walvis bay,na.
# Processing record no.223|fare,pf.
# Processing record no.224|yellowknife,ca.
# Processing record no.225|jiaojiang,cn.
# City not found... skipping.
# Processing record no.226|darhan,mn.
# Processing record no.227|husavik,is.
# Processing record no.228|adrian,us.
# Processing record no.229|ust-kuyga,ru.
# Processing record no.230|arbazh,ru.
# Processing record no.231|baykit,ru.
# Processing record no.232|matucana,pe.
# Processing record no.233|warren,us.
# Processing record no.234|goundi,td.
# Processing record no.235|yumen,cn.
# Processing record no.236|bonavista,ca.
# Processing record no.237|maceio,br.
# Processing record no.238|nome,us.
# Processing record no.239|amderma,ru.
# City not found... skipping.
# Processing record no.240|nuuk,gl.
# Processing record no.241|tumannyy,ru.
# City not found... skipping.
# Processing record no.242|morden,ca.
# Processing record no.243|waingapu,id.
# Processing record no.244|agadir,ma.
# Processing record no.245|elliot,za.
# Processing record no.246|nanortalik,gl.
# Processing record no.247|verkhnevilyuysk,ru.
# Processing record no.248|moose factory,ca.
# Processing record no.249|lewistown,us.
# Processing record no.250|sisimiut,gl.
# Processing record no.251|laramie,us.
# Processing record no.252|naqadeh,ir.
# Processing record no.253|itarema,br.
# Processing record no.254|eufaula,us.
# Processing record no.255|abu dhabi,ae.
# Processing record no.256|port augusta,au.
# Processing record no.257|asau,tv.
# City not found... skipping.
# Processing record no.258|pandan,ph.
# Processing record no.259|guelengdeng,td.
# City not found... skipping.
# Processing record no.260|aasiaat,gl.
# Processing record no.261|tatawin,tn.
# City not found... skipping.
# Processing record no.262|longyearbyen,sj.
# Processing record no.263|cidreira,br.
# Processing record no.264|tiksi,ru.
# Processing record no.265|vostok,ru.
# Processing record no.266|esqueda,mx.
# Processing record no.267|hovd,mn.
# Processing record no.268|san borja,bo.
# Processing record no.269|magrath,ca.
# Processing record no.270|kuching,my.
# Processing record no.271|sorkjosen,no.
# City not found... skipping.
# Processing record no.272|rosarito,mx.
# Processing record no.273|port blair,in.
# Processing record no.274|coihaique,cl.
# Processing record no.275|guebwiller,fr.
# Processing record no.276|rio grande,br.
# Processing record no.277|hasaki,jp.
# Processing record no.278|usagara,tz.
# Processing record no.279|constitucion,mx.
# Processing record no.280|otukpo,ng.
# Processing record no.281|poco verde,br.
# Processing record no.282|marcona,pe.
# City not found... skipping.
# Processing record no.283|imbituba,br.
# Processing record no.284|itoman,jp.
# Processing record no.285|tuatapere,nz.
# Processing record no.286|sinnamary,gf.
# Processing record no.287|farafangana,mg.
# Processing record no.288|pleasanton,us.
# Processing record no.289|lianran,cn.
# Processing record no.290|atherton,au.
# Processing record no.291|byron bay,au.
# Processing record no.292|lasa,cn.
# City not found... skipping.
# Processing record no.293|morant bay,jm.
# Processing record no.294|kahama,tz.
# Processing record no.295|hornepayne,ca.
# Processing record no.296|saldanha,za.
# Processing record no.297|bolshaya rechka,ru.
# Processing record no.298|porto torres,it.
# Processing record no.299|kologriv,ru.
# Processing record no.300|smidovich,ru.
# Processing record no.301|krasnorechenskiy,ru.
# Processing record no.302|graham,us.
# Processing record no.303|kruisfontein,za.
# Processing record no.304|naujoji akmene,lt.
# Processing record no.305|la rioja,ar.
# Processing record no.306|anadyr,ru.
# Processing record no.307|mackay,au.
# Processing record no.308|antofagasta,cl.
# Processing record no.309|anloga,gh.
# Processing record no.310|marabba,sd.
# Processing record no.311|samarai,pg.
# Processing record no.312|wulanhaote,cn.
# City not found... skipping.
# Processing record no.313|geraldton,au.
# Processing record no.314|faanui,pf.
# Processing record no.315|port hardy,ca.
# Processing record no.316|sioux lookout,ca.
# Processing record no.317|bambanglipuro,id.
# Processing record no.318|cherskiy,ru.
# Processing record no.319|adrar,dz.
# Processing record no.320|mahibadhoo,mv.
# Processing record no.321|collie,au.
# Processing record no.322|taybad,ir.
# Processing record no.323|srednekolymsk,ru.
# Processing record no.324|mareeba,au.
# Processing record no.325|mildura,au.
# Processing record no.326|port lincoln,au.
# Processing record no.327|warqla,dz.
# City not found... skipping.
# Processing record no.328|coquimbo,cl.
# Processing record no.329|gat,ly.
# City not found... skipping.
# Processing record no.330|kontagora,ng.
# Processing record no.331|taltal,cl.
# Processing record no.332|vestmannaeyjar,is.
# Processing record no.333|tabiauea,ki.
# City not found... skipping.
# Processing record no.334|caconda,ao.
# Processing record no.335|deputatskiy,ru.
# Processing record no.336|vardo,no.
# Processing record no.337|drumheller,ca.
# Processing record no.338|igrim,ru.
# Processing record no.339|norman wells,ca.
# Processing record no.340|ajdabiya,ly.
# Processing record no.341|buraydah,sa.
# Processing record no.342|ponta delgada,pt.
# Processing record no.343|sampit,id.
# Processing record no.344|acucena,br.
# Processing record no.345|weyburn,ca.
# Processing record no.346|cayenne,gf.
# Processing record no.347|kilakarai,in.
# City not found... skipping.
# Processing record no.348|huaibei,cn.
# Processing record no.349|castle rock,us.
# Processing record no.350|cockburn town,bs.
# Processing record no.351|winterberg,de.
# Processing record no.352|otofuke,jp.
# Processing record no.353|attawapiskat,ca.
# City not found... skipping.
# Processing record no.354|kupang,id.
# Processing record no.355|caravelas,br.
# Processing record no.356|waw,sd.
# City not found... skipping.
# Processing record no.357|swift current,ca.
# Processing record no.358|arlit,ne.
# Processing record no.359|rakovski,bg.
# Processing record no.360|leningradskiy,ru.
# Processing record no.361|santa maria,cv.
# Processing record no.362|severo-kurilsk,ru.
# Processing record no.363|dingtao,cn.
# Processing record no.364|tornio,fi.
# Processing record no.365|kaffrine,sn.
# Processing record no.366|wahpeton,us.
# Processing record no.367|pecos,us.
# Processing record no.368|flin flon,ca.
# Processing record no.369|sao filipe,cv.
# Processing record no.370|sorong,id.
# Processing record no.371|susangerd,ir.
# Processing record no.372|yulara,au.
# Processing record no.373|tasiilaq,gl.
# Processing record no.374|labuhan,id.
# Processing record no.375|gravdal,no.
# Processing record no.376|wahran,dz.
# City not found... skipping.
# Processing record no.377|port keats,au.
# Processing record no.378|mangla,pk.
# Processing record no.379|warri,ng.
# Processing record no.380|manta,ec.
# Processing record no.381|kota kinabalu,my.
# Processing record no.382|requena,pe.
# City not found... skipping.
# Processing record no.383|bouillante,gp.
# Processing record no.384|oga,jp.
# City not found... skipping.
# Processing record no.385|turukhansk,ru.
# Processing record no.386|gornopravdinsk,ru.
# Processing record no.387|egvekinot,ru.
# Processing record no.388|karamay,cn.
# City not found... skipping.
# Processing record no.389|moyale,et.
# Processing record no.390|savonlinna,fi.
# Processing record no.391|bolungarvik,is.
# City not found... skipping.
# Processing record no.392|sedona,us.
# Processing record no.393|vao,nc.
# Processing record no.394|el tigre,ve.
# Processing record no.395|dalby,au.
# Processing record no.396|mizan teferi,et.
# Processing record no.397|beringovskiy,ru.
# Processing record no.398|bridlington,gb.
# Processing record no.399|kutulik,ru.
# Processing record no.400|aitape,pg.
# Processing record no.401|madisonville,us.
# Processing record no.402|rocha,uy.
# Processing record no.403|skjervoy,no.
# Processing record no.404|viligili,mv.
# City not found... skipping.
# Processing record no.405|talnakh,ru.
# Processing record no.406|capim grosso,br.
# Processing record no.407|richards bay,za.
# Processing record no.408|canjulao,ph.
# Processing record no.409|edgewater,us.
# Processing record no.410|belem de sao francisco,br.
# Processing record no.411|sola,vu.
# Processing record no.412|sentyabrskiy,ru.
# City not found... skipping.
# Processing record no.413|kovernino,ru.
# Processing record no.414|kralendijk,an.
# City not found... skipping.
# Processing record no.415|lensk,ru.
# Processing record no.416|chapais,ca.
# Processing record no.417|henties bay,na.
# Processing record no.418|namatanai,pg.
# Processing record no.419|gushikawa,jp.
# Processing record no.420|saint-augustin,ca.
# Processing record no.421|lake charles,us.
# Processing record no.422|utiroa,ki.
# City not found... skipping.
# Processing record no.423|guayaramerin,bo.
# Processing record no.424|qandala,so.
# Processing record no.425|grimari,cf.
# City not found... skipping.
# Processing record no.426|micheweni,tz.
# Processing record no.427|hualmay,pe.
# Processing record no.428|bengkulu,id.
# City not found... skipping.
# Processing record no.429|sao jose da coroa grande,br.
# Processing record no.430|pokhara,np.
# Processing record no.431|pastos bons,br.
# Processing record no.432|taos,us.
# Processing record no.433|abeche,td.
# Processing record no.434|sabzevar,ir.
# Processing record no.435|ondjiva,ao.
# Processing record no.436|tunduru,tz.
# City not found... skipping.
# Processing record no.437|rognan,no.
# Processing record no.438|fortuna,us.
# Processing record no.439|mwadui,tz.
# Processing record no.440|laon,fr.
# Processing record no.441|anito,ph.
# Processing record no.442|berlevag,no.
# Processing record no.443|jalu,ly.
# Processing record no.444|cadillac,us.
# Processing record no.445|tongliao,cn.
# Processing record no.446|alofi,nu.
# Processing record no.447|mnogovershinnyy,ru.
# Processing record no.448|shahr-e babak,ir.
# Processing record no.449|huambo,ao.
# Processing record no.450|sicamous,ca.
# Processing record no.451|lima,us.
# Processing record no.452|mitchell,us.
# Processing record no.453|outjo,na.
# Processing record no.454|calca,pe.
# Processing record no.455|pietersburg,za.
# City not found... skipping.
# Processing record no.456|lieksa,fi.
# Processing record no.457|hirado,jp.
# Processing record no.458|peace river,ca.
# Processing record no.459|los llanos de aridane,es.
# Processing record no.460|port-cartier,ca.
# Processing record no.461|marion,us.
# Processing record no.462|jumla,np.
# Processing record no.463|quesnel,ca.
# Processing record no.464|kudahuvadhoo,mv.
# Processing record no.465|erenhot,cn.
# Processing record no.466|heihe,cn.
# Processing record no.467|oranjemund,na.
# Processing record no.468|margate,za.
# Processing record no.469|ngukurr,au.
# City not found... skipping.
# Processing record no.470|akdepe,tm.
# Processing record no.471|banposh,in.
# Processing record no.472|san isidro,ph.
# Processing record no.473|senneterre,ca.
# Processing record no.474|ewa beach,us.
# Processing record no.475|tucuman,ar.
# City not found... skipping.
# Processing record no.476|guicheng,cn.
# City not found... skipping.
# Processing record no.477|koslan,ru.
# Processing record no.478|tungor,ru.
# Processing record no.479|qingdao,cn.
# Processing record no.480|corinto,ni.
# Processing record no.481|ust-tsilma,ru.
# Processing record no.482|aldan,ru.
# Processing record no.483|greenwood,us.
# Processing record no.484|boa vista,br.
# Processing record no.485|karatau,kz.
# Processing record no.486|norwich,gb.
# Processing record no.487|iquitos,pe.
# Processing record no.488|sakakah,sa.
# City not found... skipping.
# Processing record no.489|palu,id.
# Processing record no.490|kununurra,au.
# Processing record no.491|juneau,us.
# Processing record no.492|evensk,ru.
# Processing record no.493|comodoro rivadavia,ar.
# Processing record no.494|pahalgam,in.
# Processing record no.495|araouane,ml.
# Processing record no.496|kloulklubed,pw.
# Processing record no.497|luanda,ao.
# Processing record no.498|paytug,uz.
# City not found... skipping.
# Processing record no.499|umzimvubu,za.
# City not found... skipping.
# Processing record no.500|shahrud,ir.
# Processing record no.501|baglung,np.
# Processing record no.502|saint-paul,re.
# Processing record no.503|hambantota,lk.
# Processing record no.504|celestun,mx.
# Processing record no.505|dudinka,ru.
# Processing record no.506|tutoia,br.
# Processing record no.507|kholodnyy,ru.
# Processing record no.508|vilyuysk,ru.
# Processing record no.509|usinsk,ru.
# Processing record no.510|novopokrovka,ua.
# Processing record no.511|fereydun kenar,ir.
# Processing record no.512|kaitangata,nz.
# Processing record no.513|svetlyy,ru.
# City not found... skipping.
# Processing record no.514|oussouye,sn.
# Processing record no.515|sorland,no.
# Processing record no.516|la asuncion,ve.
# Processing record no.517|opuwo,na.
# Processing record no.518|elizabeth city,us.
# Processing record no.519|huadian,cn.
# Processing record no.520|zheleznodorozhnyy,ru.
# Processing record no.521|yambio,sd.
# City not found... skipping.
# Processing record no.522|san ramon,bo.
# Processing record no.523|puerto palomas,mx.
# Processing record no.524|klyuchi,ru.
# Processing record no.525|nam tha,la.
# City not found... skipping.
# Processing record no.526|santiago de cao,pe.
# Processing record no.527|beidao,cn.
# Processing record no.528|tahta,eg.
# Processing record no.529|acuitzio,mx.
# Processing record no.530|tignere,cm.
# Processing record no.531|wukari,ng.
# Processing record no.532|ilmenau,de.
# Processing record no.533|channahon,us.
# Processing record no.534|tazovskiy,ru.
# Processing record no.535|burgeo,ca.
# Processing record no.536|esna,eg.
# City not found... skipping.
# Processing record no.537|tchaourou,bj.
# Processing record no.538|zapolyarnyy,ru.
# Processing record no.539|pudozh,ru.
# Processing record no.540|sheridan,us.
# Processing record no.541|takoradi,gh.
# Processing record no.542|teguldet,ru.
# Processing record no.543|mookane,bw.
# Processing record no.544|dongning,cn.
# Processing record no.545|sarkikaraagac,tr.
# Processing record no.546|touros,br.
# Processing record no.547|hendijan,ir.
# City not found... skipping.
# Processing record no.548|bombay,in.
# City not found... skipping.
# Processing record no.549|rutana,bi.
# Processing record no.550|panaba,mx.
# Processing record no.551|seoul,kr.
# Processing record no.552|mount isa,au.
# Processing record no.553|olga,ru.
# Processing record no.554|belyy yar,ru.
# Processing record no.555|oranjestad,aw.
# Processing record no.556|the valley,ai.
# Processing record no.557|birakan,ru.
# Processing record no.558|kenora,ca.
# Processing record no.559|esmeraldas,ec.
# Processing record no.560|havre-saint-pierre,ca.
# Processing record no.561|bolu,tr.
# Processing record no.562|lagoa vermelha,br.
# Processing record no.563|gamba,ga.
# Processing record no.564|iglino,ru.
# Processing record no.565|coahuayana,mx.
# Processing record no.566|arawa,pg.
# Processing record no.567|francistown,bw.
# Processing record no.568|kytlym,ru.
# City not found... skipping.
# Processing record no.569|burica,pa.
# City not found... skipping.
# Processing record no.570|polazna,ru.
# Processing record no.571|salisbury,gb.
# Processing record no.572|grand river south east,mu.
# City not found... skipping.
# Processing record no.573|karachi,pk.
# Processing record no.574|aloleng,ph.
# Processing record no.575|itaituba,br.
# Processing record no.576|pimentel,pe.
# Processing record no.577|bahia de caraquez,ec.
# Processing record no.578|kuusamo,fi.
# Processing record no.579|westpunt,an.
# City not found... skipping.
# Processing record no.580|huarmey,pe.
# Processing record no.581|allada,bj.
# Processing record no.582|salinopolis,br.
# Processing record no.583|lulea,se.
# Processing record no.584|zatoka,ua.
# Processing record no.585|saint simons,us.
# Processing record no.586|manoel urbano,br.
# Processing record no.587|polillo,ph.
# Processing record no.588|azul,ar.
# Processing record no.589|chizhou,cn.
# Processing record no.590|gunjur,gm.
# Processing record no.591|freeport,us.
# Processing record no.592|warrington,us.
# Processing record no.593|mittersill,at.
# Processing record no.594|ko samui,th.
# Processing record no.595|bambous virieux,mu.
# Processing record no.596|khovu-aksy,ru.
# Processing record no.597|college,us.
# Processing record no.598|charters towers,au.
# Processing record no.599|guerrero negro,mx.
# Processing record no.600|gloversville,us.
# Processing record no.601|yanan,cn.
# City not found... skipping.
# Processing record no.602|olafsvik,is.
# City not found... skipping.
# Processing record no.603|pervoye maya,ru.
# Processing record no.604|chissamba,ao.
# City not found... skipping.
# Processing record no.605|samalaeulu,ws.
# City not found... skipping.
# Processing record no.606|paradwip,in.
# City not found... skipping.
# Processing record no.607|majene,id.
# Processing record no.608|axim,gh.
# Processing record no.609|chimbote,pe.
# Processing record no.610|tukrah,ly.
# City not found... skipping.
# Processing record no.611|sarh,td.
# Processing record no.612|saint pete beach,us.
# Processing record no.613|sur,om.
# Processing record no.614|san cristobal,ec.
# Processing record no.615|yuzhno-sukhokumsk,ru.
# Processing record no.616|odweyne,so.
# City not found... skipping.
# Processing record no.617|great yarmouth,gb.
# Processing record no.618|ayan,ru.
# City not found... skipping.
# Processing record no.619|port-gentil,ga.
# Processing record no.620|dourbali,td.
# Processing record no.621|pasni,pk.
# Processing record no.622|hunchun,cn.
# Processing record no.623|bethel,us.
# Processing record no.624|caucaia,br.
# Processing record no.625|batemans bay,au.
# Processing record no.626|biak,id.
# Processing record no.627|cabras,it.
# Processing record no.628|winslow,us.
# Processing record no.629|karlskrona,se.
# Processing record no.630|ribnitz-damgarten,de.
# Processing record no.631|san policarpo,ph.
# Processing record no.632|saint-felicien,ca.
# Processing record no.633|wamba,cd.
# Processing record no.634|shakhtinsk,kz.
# --------------------------
# Data Retrieval Complete
# --------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citydata=pd.DataFrame({"City":City,"Country":Country,"Latitude":Lat,"Longitude": Lon,
                      "Max. Temp.(C)": Temp, "Humidity(%)": Hum, "Cloudiness(%)": Cloud,
                      "Windspeed(mph)": Wind, "Date": Date})
citydata=citydata.drop_duplicates(["City","Country"])
#print count for the df to ensure there are >500 cities
print(citydata.count())
#print the output csv file and drop the index column
output = citydata.to_csv(output_data_file, index=False)
output
#Preview the dataframe
citydata.head()
#previewing the dataframe revealed that date column was in unix format. 
#convert date from unix timestamp to yyyy-mm-dd
from datetime import datetime, timedelta
start = datetime(1970, 1, 1)  # Unix epoch start time
citydata['Date'] = citydata['Date'].apply(lambda x: start + timedelta(seconds=x))
citydata['Date'] = citydata['Date'].apply(lambda x: x.strftime('%Y-%m-%d'))
#preview the dataframe again
citydata.head()
# Out:
# City              555
# Country           555
# Latitude          555
# Longitude         555
# Max. Temp.(C)     555
# Humidity(%)       555
# Cloudiness(%)     555
# Windspeed(mph)    555
# Date              555
# dtype: int64
#            City Country  Latitude  Longitude  Max. Temp.(C)  Humidity(%)  \
# 0  Puerto Ayora      EC     -0.74     -90.35          28.00           65
# 1        Palmer      US     61.60    -149.11          11.11           81
# 2    Chokurdakh      RU     70.62     147.90          -0.18           87
# 3    Noicattaro      IT     41.03      16.99          20.56           68
# 4        Barrow      US     39.51     -90.40          25.56           46
#
#    Cloudiness(%)  Windspeed(mph)        Date
# 0             20            9.30  2019-06-02
# 1             90            1.50  2019-06-02
# 2             96            6.08  2019-06-02
# 3             20            1.00  2019-06-02
# 4              1            5.70  2019-06-02

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(y=citydata["Max. Temp.(C)"],x=citydata["Latitude"], color="#4682b4",
            edgecolors="black",marker='o',alpha=1)
plt.title(f'City Latitude vs Max Temperature, ({citydata["Date"][0]})')
plt.ylabel('Max Temperature(Celsius)')
plt.xlabel('Latitude')
plt.xlim(-85,85)
plt.grid(True)
plt.show()
plt.savefig("Latitude vs. Max. Temperature.jpeg")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(y=citydata["Humidity(%)"],x=citydata["Latitude"], color="#4682b4",
            edgecolors="black",marker='o',alpha=1)
plt.title(f'City Latitude vs Humidity, ({citydata["Date"][0]})')
plt.ylabel('Humidity(%)')
#Set ylim to ignore 200%+ humidity values for Iquitos,PE and Paita, PE, which are most likely typos 
plt.ylim(0,105)
plt.xlabel('Latitude')
plt.grid(True)
plt.show()
plt.savefig("City Latitude vs. Humidity.jpeg")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(y=citydata["Cloudiness(%)"],x=citydata["Latitude"], color="#4682b4",
            edgecolors="black",marker='o',alpha=1)
plt.title(f'City Latitude vs Cloudiness, ({citydata["Date"][0]})')
plt.ylabel('Cloudiness(%)')
#Set ylim for optimal view of datapoints
plt.ylim(-5,105)
plt.xlabel('Latitude')
plt.grid(True)
plt.show()
plt.savefig("City Latitude vs. Cloudiness.jpeg")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(y=citydata["Windspeed(mph)"],x=citydata["Latitude"], color="#4682b4",
            edgecolors="black",marker='o',alpha=1)
plt.title(f'City Latitude vs Windspeed, ({citydata["Date"][0]})')
plt.ylabel('Windspeed(mph)')
plt.xlabel('Latitude')
plt.grid(True)
plt.show()
plt.savefig("City Latitude vs. Windspeed.jpeg")

# %%
#### Longitude vs. Humidity Plot

# %%
plt.scatter(y=citydata["Humidity(%)"],x=citydata["Longitude"], color="#4682b4",
            edgecolors="black",marker='o',alpha=1)
plt.title(f'City Longitude vs Humidity, ({citydata["Date"][0]})')
plt.ylabel('Humidity(%)')
#Set ylim to ignore 200%+ humidity values for Iquitos,PE and Paita, PE, which are most likely typos 
plt.ylim(0,105)
plt.xlabel('Longitude')
plt.grid(True)
plt.show()
plt.savefig("City Longitude vs. Humidity.jpeg")

# %%
plt.scatter(y=citydata["Max. Temp.(C)"],x=citydata["Longitude"], color="#4682b4",
            edgecolors="black",marker='o',alpha=1)
plt.title(f'City Longitude vs Max. Temp., ({citydata["Date"][0]})')
plt.ylabel('Max. Temp.(C)')
#Set ylim to ignore 200%+ humidity values for Iquitos,PE and Paita, PE, which are most likely typos 
plt.ylim(-100,100)
plt.xlabel('Longitude')
plt.grid(True)
plt.show()
plt.savefig("City Longitude vs. Max. Temp(C).jpeg")

# %%
plt.scatter(y=citydata["Windspeed(mph)"],x=citydata["Longitude"], color="#4682b4",
            edgecolors="black",marker='o',alpha=1)
plt.title(f'City Longitude vs Windspeed, ({citydata["Date"][0]})')
plt.ylabel('Windspeed(mph)')
plt.xlabel('Longitude')
plt.grid(True)
plt.show()
plt.savefig("City Longitude vs. Windspeed(mph).jpeg")
